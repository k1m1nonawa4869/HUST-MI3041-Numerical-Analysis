# %% [markdown]
# Phương pháp chia đôi (Bisection Method)
#
# # Điều kiện:
#
#     - (a,b) là khoảng cách ly nghiệm
#
#     - f(x) liên tục trên (a,b)
#
#     - f(a) * f(b) < 0

# %% [markdown]
# # Thuật toán:
#
# 1. Chọn khoảng [a_0,b_0] ban đầu sao cho `f(a_0)*f(b_0) < 0`.
#
# 2. Lấy `c_1 = (a_0 + b_0)/2`
#
# 3. Xác định khoảng tiếp theo [a_1, b_1]:
#
#    a. Nếu `f(a_0) * f(c_1) < 0`, giữ a_1 = a_0 và cập nhật `b_1 = c_1`.
#
#    b. Nếu `f(b_0) * f(c_1) < 0`, cập nhật `a_1 = c_1` và giữ b_1 = b_0.
#
# 4. Lặp lại các bước (2) và (3) cho đến khi:
#
#    a. c_n là nghiệm của phương trình, hoặc
#
#    b. khoảng [a_n, b_n] thỏa mãn điều kiện dừng
#
# 5. In giá trị `c_n` (giá trị c sau n lần lặp)

# %% [markdown]
# # Áp dụng

# %%
import math

def f(x):
    pass

def sign(x):
    value = f(x)
    if value > 0:
        return 1
    elif value < 0:
        return -1
    else:
        return 0

# %% [markdown]
# ## 1. Tiên nghiệm - số lần lặp:

# %% [markdown]
# ### Ví dụ 1: Số lần lặp

# %%
def bisection_iteration_v1 (a,b,n):
    #Error function
    if (f(a) * f(b) >= 0):
        print("You have not assumed right a and b\n")
        return

    #Implementing Bisection Method
    temp_c = 0
    for i in range(n):
        # Find middle point
        c = (a+b) / 2.0

        print(f"n={i:<2};a={a:<25};b={b:<25};c={c:<25};f(a)={f(a):<25};f(b)={f(b):<25};f(c)={f(c):<25};delta={abs(c-temp_c):<25}")

        # Decide the side to repeat the steps
        if f(c) == 0:
            break
        elif (f(c) * sign(a) < 0):
            b = c
        else:
            a = c

        temp_c = c
    
    print(f"The value of root is: {c}")
    return c

# %%
def f(x):
    return math.e**x - math.cos(2*x)
a = -1
b = -0.1
n = 15

bisection_iteration_v1 (a, b, n)
# Out:
# n=0 ;a=-1                       ;b=-0.1                     ;c=-0.55                    ;f(a)=0.7840262777185847       ;f(b)=-0.07522915980528211     ;f(c)=0.12335368895490934      ;delta=0.55
# n=1 ;a=-0.55                    ;b=-0.1                     ;c=-0.325                   ;f(a)=0.12335368895490934      ;f(b)=-0.07522915980528211     ;f(c)=-0.07355644490698365     ;delta=0.22500000000000003
# n=2 ;a=-0.55                    ;b=-0.325                   ;c=-0.4375                  ;f(a)=0.12335368895490934      ;f(b)=-0.07355644490698365     ;f(c)=0.004651668264566866     ;delta=0.11249999999999999
# n=3 ;a=-0.4375                  ;b=-0.325                   ;c=-0.38125                 ;f(a)=0.004651668264566866     ;f(b)=-0.07355644490698365     ;f(c)=-0.040104327315815924    ;delta=0.05625000000000002
# n=4 ;a=-0.4375                  ;b=-0.38125                 ;c=-0.409375                ;f(a)=0.004651668264566866     ;f(b)=-0.040104327315815924    ;f(c)=-0.019069445162667953    ;delta=0.02812500000000001
# n=5 ;a=-0.4375                  ;b=-0.409375                ;c=-0.4234375               ;f(a)=0.004651668264566866     ;f(b)=-0.019069445162667953    ;f(c)=-0.007535571864755286    ;delta=0.014062500000000033
# n=6 ;a=-0.4375                  ;b=-0.4234375               ;c=-0.43046875              ;f(a)=0.004651668264566866     ;f(b)=-0.007535571864755286    ;f(c)=-0.00152246410868484     ;delta=0.007031249999999989
# n=7 ;a=-0.4375                  ;b=-0.43046875              ;c=-0.433984375             ;f(a)=0.004651668264566866     ;f(b)=-0.00152246410868484     ;f(c)=0.001544620136878505     ;delta=0.0035156249999999667
# n=8 ;a=-0.433984375             ;b=-0.43046875              ;c=-0.4322265625            ;f(a)=0.001544620136878505     ;f(b)=-0.00152246410868484     ;f(c)=6.064203625921749e-06    ;delta=0.0017578124999999556
# n=9 ;a=-0.4322265625            ;b=-0.43046875              ;c=-0.43134765625000004     ;f(a)=6.064203625921749e-06    ;f(b)=-0.00152246410868484     ;f(c)=-0.0007594556907252192   ;delta=0.0008789062499999778
# n=10;a=-0.4322265625            ;b=-0.43134765625000004     ;c=-0.43178710937500003     ;f(a)=6.064203625921749e-06    ;f(b)=-0.0007594556907252192   ;f(c)=-0.0003770093926284135   ;delta=0.0004394531249999889
# n=11;a=-0.4322265625            ;b=-0.43178710937500003     ;c=-0.4320068359375         ;f(a)=6.064203625921749e-06    ;f(b)=-0.0003770093926284135   ;f(c)=-0.00018555097106731644  ;delta=0.0002197265624999667
# n=12;a=-0.4322265625            ;b=-0.4320068359375         ;c=-0.43211669921875        ;f(a)=6.064203625921749e-06    ;f(b)=-0.00018555097106731644  ;f(c)=-8.976297339802208e-05   ;delta=0.0001098632812500111
# n=13;a=-0.4322265625            ;b=-0.43211669921875        ;c=-0.43217163085937504     ;f(a)=6.064203625921749e-06    ;f(b)=-8.976297339802208e-05   ;f(c)=-4.185428174718897e-05   ;delta=5.493164062503331e-05
# n=14;a=-0.4322265625            ;b=-0.43217163085937504     ;c=-0.43219909667968753     ;f(a)=6.064203625921749e-06    ;f(b)=-4.185428174718897e-05   ;f(c)=-1.7896263206140794e-05  ;delta=2.7465820312488898e-05
# The value of root is: -0.43219909667968753
# -0.43219909667968753

# %% [markdown]
# ### Ví dụ 2: Sai số tuyệt đối
# Sử dụng `|x_n - x| <= (b-a)/2^n < epsilon` --> `n > log_2 ((b-a)/e)`

# %%
def f(x):
    return math.tan(x/4) - 1
a = 3
b = 3.2
e = pow(10, -6)
n = math.floor(math.log2((b-a)/e)) + 1 

bisection_iteration_v1 (a, b, n)
# Out:
# n=0 ;a=3                        ;b=3.2                      ;c=3.1                      ;f(a)=-0.06840354005592753     ;f(b)=0.02963855705036411      ;f(c)=-0.02058304278339118     ;delta=3.1
# n=1 ;a=3.1                      ;b=3.2                      ;c=3.1500000000000004       ;f(a)=-0.02058304278339118     ;f(b)=0.02963855705036411      ;f(c)=0.004212533465392854     ;delta=0.050000000000000266
# n=2 ;a=3.1                      ;b=3.1500000000000004       ;c=3.125                    ;f(a)=-0.02058304278339118     ;f(b)=0.004212533465392854     ;f(c)=-0.008262101636731356    ;delta=0.025000000000000355
# n=3 ;a=3.125                    ;b=3.1500000000000004       ;c=3.1375                   ;f(a)=-0.008262101636731356    ;f(b)=0.004212533465392854     ;f(c)=-0.002044235920871773    ;delta=0.012500000000000178
# n=4 ;a=3.1375                   ;b=3.1500000000000004       ;c=3.1437500000000003       ;f(a)=-0.002044235920871773    ;f(b)=0.004212533465392854     ;f(c)=0.0010792553916858516    ;delta=0.006250000000000089
# n=5 ;a=3.1375                   ;b=3.1437500000000003       ;c=3.140625                 ;f(a)=-0.002044235920871773    ;f(b)=0.0010792553916858516    ;f(c)=-0.00048370978845424517  ;delta=0.0031250000000002665
# n=6 ;a=3.140625                 ;b=3.1437500000000003       ;c=3.1421875000000004       ;f(a)=-0.00048370978845424517  ;f(b)=0.0010792553916858516    ;f(c)=0.0002974674441567071    ;delta=0.0015625000000003553
# n=7 ;a=3.140625                 ;b=3.1421875000000004       ;c=3.14140625               ;f(a)=-0.00048370978845424517  ;f(b)=0.0002974674441567071    ;f(c)=-9.319745187907902e-05   ;delta=0.0007812500000001776
# n=8 ;a=3.14140625               ;b=3.1421875000000004       ;c=3.1417968750000003       ;f(a)=-9.319745187907902e-05   ;f(b)=0.0002974674441567071    ;f(c)=0.00010211591875641801   ;delta=0.0003906250000000888
# n=9 ;a=3.14140625               ;b=3.1417968750000003       ;c=3.1416015625             ;f(a)=-9.319745187907902e-05   ;f(b)=0.00010211591875641801   ;f(c)=4.454465024394949e-06    ;delta=0.00019531250000026645
# n=10;a=3.14140625               ;b=3.1416015625             ;c=3.14150390625            ;f(a)=-9.319745187907902e-05   ;f(b)=4.454465024394949e-06    ;f(c)=-4.4372685414462154e-05  ;delta=9.765624999991118e-05
# n=11;a=3.14150390625            ;b=3.1416015625             ;c=3.141552734375           ;f(a)=-4.4372685414462154e-05  ;f(b)=4.454465024394949e-06    ;f(c)=-1.9959408206426943e-05  ;delta=4.8828124999733546e-05
# n=12;a=3.141552734375           ;b=3.1416015625             ;c=3.1415771484375          ;f(a)=-1.9959408206426943e-05  ;f(b)=4.454465024394949e-06    ;f(c)=-7.752546095640689e-06   ;delta=2.4414062500088818e-05
# n=13;a=3.1415771484375          ;b=3.1416015625             ;c=3.14158935546875         ;f(a)=-7.752546095640689e-06   ;f(b)=4.454465024394949e-06    ;f(c)=-1.6490591617790429e-06  ;delta=1.2207031250266454e-05
# n=14;a=3.14158935546875         ;b=3.1416015625             ;c=3.141595458984375        ;f(a)=-1.6490591617790429e-06  ;f(b)=4.454465024394949e-06    ;f(c)=1.4026982746440098e-06   ;delta=6.103515624911182e-06
# n=15;a=3.14158935546875         ;b=3.141595458984375        ;c=3.141592407226563        ;f(a)=-1.6490591617790429e-06  ;f(b)=1.4026982746440098e-06   ;f(c)=-1.2318160758084673e-07  ;delta=3.0517578122335465e-06
# n=16;a=3.141592407226563        ;b=3.141595458984375        ;c=3.1415939331054688       ;f(a)=-1.2318160758084673e-07  ;f(b)=1.4026982746440098e-06   ;f(c)=6.397580423200822e-07    ;delta=1.5258789058947286e-06
# n=17;a=3.141592407226563        ;b=3.1415939331054688       ;c=3.141593170166016        ;f(a)=-1.2318160758084673e-07  ;f(b)=6.397580423200822e-07    ;f(c)=2.582881446500096e-07    ;delta=7.629394529473643e-07
# The value of root is: 3.141593170166016
# 3.141593170166016

# %% [markdown]
# ### Ví dụ 3: Chữ số đáng tin:
# i là chữ số đáng tin <-> delta_a <= 1/2 thứ nguyên của chữ số i

# %%
def f(x):
    return math.log(x) - 1
a = 2
b = 3
e = 0.5 * pow(10, -7) #8 chữ số đáng tin, 1 chữ số ở phần nguyên
n = math.floor(math.log2((b-a)/e)) + 1

c = bisection_iteration_v1 (a, b, n)

round(c,7) #Làm tròn 7 chữ số thập phân
# Out:
# n=0 ;a=2                        ;b=3                        ;c=2.5                      ;f(a)=-0.3068528194400547      ;f(b)=0.09861228866810978      ;f(c)=-0.0837092681258449      ;delta=2.5
# n=1 ;a=2.5                      ;b=3                        ;c=2.75                     ;f(a)=-0.0837092681258449      ;f(b)=0.09861228866810978      ;f(c)=0.011600911678479875     ;delta=0.25
# n=2 ;a=2.5                      ;b=2.75                     ;c=2.625                    ;f(a)=-0.0837092681258449      ;f(b)=0.011600911678479875     ;f(c)=-0.034919103956412956    ;delta=0.125
# n=3 ;a=2.625                    ;b=2.75                     ;c=2.6875                   ;f(a)=-0.034919103956412956    ;f(b)=0.011600911678479875     ;f(c)=-0.01138860654621876     ;delta=0.0625
# n=4 ;a=2.6875                   ;b=2.75                     ;c=2.71875                  ;f(a)=-0.01138860654621876     ;f(b)=0.011600911678479875     ;f(c)=0.00017221585485716062   ;delta=0.03125
# n=5 ;a=2.6875                   ;b=2.71875                  ;c=2.703125                 ;f(a)=-0.01138860654621876     ;f(b)=0.00017221585485716062   ;f(c)=-0.005591488861892868    ;delta=0.015625
# n=6 ;a=2.703125                 ;b=2.71875                  ;c=2.7109375                ;f(a)=-0.005591488861892868    ;f(b)=0.00017221585485716062   ;f(c)=-0.0027054839727579383   ;delta=0.0078125
# n=7 ;a=2.7109375                ;b=2.71875                  ;c=2.71484375               ;f(a)=-0.0027054839727579383   ;f(b)=0.00017221585485716062   ;f(c)=-0.001265598914770294    ;delta=0.00390625
# n=8 ;a=2.71484375               ;b=2.71875                  ;c=2.716796875              ;f(a)=-0.001265598914770294    ;f(b)=0.00017221585485716062   ;f(c)=-0.0005464331160648372   ;delta=0.001953125
# n=9 ;a=2.716796875              ;b=2.71875                  ;c=2.7177734375             ;f(a)=-0.0005464331160648372   ;f(b)=0.00017221585485716062   ;f(c)=-0.00018704407356229247  ;delta=0.0009765625
# n=10;a=2.7177734375             ;b=2.71875                  ;c=2.71826171875            ;f(a)=-0.00018704407356229247  ;f(b)=0.00017221585485716062   ;f(c)=-7.397975890666153e-06   ;delta=0.00048828125
# n=11;a=2.71826171875            ;b=2.71875                  ;c=2.718505859375           ;f(a)=-7.397975890666153e-06   ;f(b)=0.00017221585485716062   ;f(c)=8.241297212419063e-05    ;delta=0.000244140625
# n=12;a=2.71826171875            ;b=2.718505859375           ;c=2.7183837890625          ;f(a)=-7.397975890666153e-06   ;f(b)=8.241297212419063e-05    ;f(c)=3.75085063675229e-05     ;delta=0.0001220703125
# n=13;a=2.71826171875            ;b=2.7183837890625          ;c=2.71832275390625         ;f(a)=-7.397975890666153e-06   ;f(b)=3.75085063675229e-05     ;f(c)=1.5055517312401179e-05   ;delta=6.103515625e-05
# n=14;a=2.71826171875            ;b=2.71832275390625         ;c=2.718292236328125        ;f(a)=-7.397975890666153e-06   ;f(b)=1.5055517312401179e-05   ;f(c)=3.82883373095666e-06     ;delta=3.0517578125e-05
# n=15;a=2.71826171875            ;b=2.718292236328125        ;c=2.7182769775390625       ;f(a)=-7.397975890666153e-06   ;f(b)=3.82883373095666e-06     ;f(c)=-1.7845553247353152e-06  ;delta=1.52587890625e-05
# n=16;a=2.7182769775390625       ;b=2.718292236328125        ;c=2.7182846069335938       ;f(a)=-1.7845553247353152e-06  ;f(b)=3.82883373095666e-06     ;f(c)=1.022143141904408e-06    ;delta=7.62939453125e-06
# n=17;a=2.7182769775390625       ;b=2.7182846069335938       ;c=2.718280792236328        ;f(a)=-1.7845553247353152e-06  ;f(b)=1.022143141904408e-06    ;f(c)=-3.812051067031419e-07   ;delta=3.814697265625e-06
# n=18;a=2.718280792236328        ;b=2.7182846069335938       ;c=2.718282699584961        ;f(a)=-3.812051067031419e-07   ;f(b)=1.022143141904408e-06    ;f(c)=3.204692637925888e-07    ;delta=1.9073486328125e-06
# n=19;a=2.718280792236328        ;b=2.718282699584961        ;c=2.7182817459106445       ;f(a)=-3.812051067031419e-07   ;f(b)=3.204692637925888e-07    ;f(c)=-3.0367860004432146e-08  ;delta=9.5367431640625e-07
# n=20;a=2.7182817459106445       ;b=2.718282699584961        ;c=2.7182822227478027       ;f(a)=-3.0367860004432146e-08  ;f(b)=3.204692637925888e-07    ;f(c)=1.4505071721515606e-07   ;delta=4.76837158203125e-07
# n=21;a=2.7182817459106445       ;b=2.7182822227478027       ;c=2.7182819843292236       ;f(a)=-3.0367860004432146e-08  ;f(b)=1.4505071721515606e-07   ;f(c)=5.734143249114254e-08    ;delta=2.384185791015625e-07
# n=22;a=2.7182817459106445       ;b=2.7182819843292236       ;c=2.718281865119934        ;f(a)=-3.0367860004432146e-08  ;f(b)=5.734143249114254e-08    ;f(c)=1.348678724255592e-08    ;delta=1.1920928955078125e-07
# n=23;a=2.7182817459106445       ;b=2.718281865119934        ;c=2.7182818055152893       ;f(a)=-3.0367860004432146e-08  ;f(b)=1.348678724255592e-08    ;f(c)=-8.440536158893508e-09   ;delta=5.960464477539063e-08
# n=24;a=2.7182818055152893       ;b=2.718281865119934        ;c=2.7182818353176117       ;f(a)=-8.440536158893508e-09   ;f(b)=1.348678724255592e-08    ;f(c)=2.5231254863200547e-09   ;delta=2.9802322387695312e-08
# The value of root is: 2.7182818353176117
# 2.7182818

# %% [markdown]
# ## 2. Hậu nghiệm:

# %% [markdown]
# ### Ví dụ 1: Sai số tuyệt đối
#
# Đánh giá sai số: `|x_n - x| <= |b_n - a_n| = |x_n - x_(n-1)| < epsilon`

# %%
def bisection_recursion_v1 (a,b,e):
    #Error function
    if (f(a) * f(b) >= 0):
        print("You have not assumed right a and b\n")
        return

    #Implementing Bisection Method
    i = 0; temp_c = 0;
    while True:
        # Find middle point
        c = (a+b)/ 2.0

        print(f"n={i:<2};a={a:<25};b={b:<25};c={c:<25};f(a)={f(a):<25};f(b)={f(b):<25};f(c)={f(c):<25};delta={abs(c-temp_c):<25}")
        
        # Decide the side to repeat the steps
        if (f(c) == 0.0):
            break
        elif (f(c)*sign(a) < 0):
            b = c
        else:
            a = c 

        # stopping rule
        if (i != 0) and (b-a < e):
            break
        else:
            temp_c = c
            i += 1
    
    print(f"The value of root is: {c}")
    return c

# %%
def f(x):
    return pow(x,3)+4*pow(x,2)-10
a = 1
b = 2
e = 0.5 * pow(10, -9) #10 chữ số đáng tin, 1 chữ số ở phần nguyên

c = bisection_recursion_v1 (a, b, e)
round(c,9) #Làm tròn 9 chữ số thập phân
# Out:
# n=0 ;a=1                        ;b=2                        ;c=1.5                      ;f(a)=-5                       ;f(b)=14                       ;f(c)=2.375                    ;delta=1.5
# n=1 ;a=1                        ;b=1.5                      ;c=1.25                     ;f(a)=-5                       ;f(b)=2.375                    ;f(c)=-1.796875                ;delta=0.25
# n=2 ;a=1.25                     ;b=1.5                      ;c=1.375                    ;f(a)=-1.796875                ;f(b)=2.375                    ;f(c)=0.162109375              ;delta=0.125
# n=3 ;a=1.25                     ;b=1.375                    ;c=1.3125                   ;f(a)=-1.796875                ;f(b)=0.162109375              ;f(c)=-0.848388671875          ;delta=0.0625
# n=4 ;a=1.3125                   ;b=1.375                    ;c=1.34375                  ;f(a)=-0.848388671875          ;f(b)=0.162109375              ;f(c)=-0.350982666015625       ;delta=0.03125
# n=5 ;a=1.34375                  ;b=1.375                    ;c=1.359375                 ;f(a)=-0.350982666015625       ;f(b)=0.162109375              ;f(c)=-0.09640884399414062     ;delta=0.015625
# n=6 ;a=1.359375                 ;b=1.375                    ;c=1.3671875                ;f(a)=-0.09640884399414062     ;f(b)=0.162109375              ;f(c)=0.03235578536987305      ;delta=0.0078125
# n=7 ;a=1.359375                 ;b=1.3671875                ;c=1.36328125               ;f(a)=-0.09640884399414062     ;f(b)=0.03235578536987305      ;f(c)=-0.03214997053146362     ;delta=0.00390625
# n=8 ;a=1.36328125               ;b=1.3671875                ;c=1.365234375              ;f(a)=-0.03214997053146362     ;f(b)=0.03235578536987305      ;f(c)=7.202476263046265e-05    ;delta=0.001953125
# n=9 ;a=1.36328125               ;b=1.365234375              ;c=1.3642578125             ;f(a)=-0.03214997053146362     ;f(b)=7.202476263046265e-05    ;f(c)=-0.01604669075459242     ;delta=0.0009765625
# n=10;a=1.3642578125             ;b=1.365234375              ;c=1.36474609375            ;f(a)=-0.01604669075459242     ;f(b)=7.202476263046265e-05    ;f(c)=-0.007989262812770903    ;delta=0.00048828125
# n=11;a=1.36474609375            ;b=1.365234375              ;c=1.364990234375           ;f(a)=-0.007989262812770903    ;f(b)=7.202476263046265e-05    ;f(c)=-0.003959101522923447    ;delta=0.000244140625
# n=12;a=1.364990234375           ;b=1.365234375              ;c=1.3651123046875          ;f(a)=-0.003959101522923447    ;f(b)=7.202476263046265e-05    ;f(c)=-0.0019436590100667672   ;delta=0.0001220703125
# n=13;a=1.3651123046875          ;b=1.365234375              ;c=1.36517333984375         ;f(a)=-0.0019436590100667672   ;f(b)=7.202476263046265e-05    ;f(c)=-0.000935847281880342    ;delta=6.103515625e-05
# n=14;a=1.36517333984375         ;b=1.365234375              ;c=1.365203857421875        ;f(a)=-0.000935847281880342    ;f(b)=7.202476263046265e-05    ;f(c)=-0.00043191879925075227  ;delta=3.0517578125e-05
# n=15;a=1.365203857421875        ;b=1.365234375              ;c=1.3652191162109375       ;f(a)=-0.00043191879925075227  ;f(b)=7.202476263046265e-05    ;f(c)=-0.0001799489032272561   ;delta=1.52587890625e-05
# n=16;a=1.3652191162109375       ;b=1.365234375              ;c=1.3652267456054688       ;f(a)=-0.0001799489032272561   ;f(b)=7.202476263046265e-05    ;f(c)=-5.3962541528562724e-05  ;delta=7.62939453125e-06
# n=17;a=1.3652267456054688       ;b=1.365234375              ;c=1.3652305603027344       ;f(a)=-5.3962541528562724e-05  ;f(b)=7.202476263046265e-05    ;f(c)=9.030992742964372e-06    ;delta=3.814697265625e-06
# n=18;a=1.3652267456054688       ;b=1.3652305603027344       ;c=1.3652286529541016       ;f(a)=-5.3962541528562724e-05  ;f(b)=9.030992742964372e-06    ;f(c)=-2.2465803844795573e-05  ;delta=1.9073486328125e-06
# n=19;a=1.3652286529541016       ;b=1.3652305603027344       ;c=1.365229606628418        ;f(a)=-2.2465803844795573e-05  ;f(b)=9.030992742964372e-06    ;f(c)=-6.7174129139147e-06     ;delta=9.5367431640625e-07
# n=20;a=1.365229606628418        ;b=1.3652305603027344       ;c=1.3652300834655762       ;f(a)=-6.7174129139147e-06     ;f(b)=9.030992742964372e-06    ;f(c)=1.1567880733309721e-06   ;delta=4.76837158203125e-07
# n=21;a=1.365229606628418        ;b=1.3652300834655762       ;c=1.365229845046997        ;f(a)=-6.7174129139147e-06     ;f(b)=1.1567880733309721e-06   ;f(c)=-2.780312879480107e-06   ;delta=2.384185791015625e-07
# n=22;a=1.365229845046997        ;b=1.3652300834655762       ;c=1.3652299642562866       ;f(a)=-2.780312879480107e-06   ;f(b)=1.1567880733309721e-06   ;f(c)=-8.117625185377619e-07   ;delta=1.1920928955078125e-07
# n=23;a=1.3652299642562866       ;b=1.3652300834655762       ;c=1.3652300238609314       ;f(a)=-8.117625185377619e-07   ;f(b)=1.1567880733309721e-06   ;f(c)=1.7251274897489566e-07   ;delta=5.960464477539063e-08
# n=24;a=1.3652299642562866       ;b=1.3652300238609314       ;c=1.365229994058609        ;f(a)=-8.117625185377619e-07   ;f(b)=1.7251274897489566e-07   ;f(c)=-3.196248918868605e-07   ;delta=2.9802322387695312e-08
# n=25;a=1.365229994058609        ;b=1.3652300238609314       ;c=1.3652300089597702       ;f(a)=-3.196248918868605e-07   ;f(b)=1.7251274897489566e-07   ;f(c)=-7.355607323233926e-08   ;delta=1.4901161193847656e-08
# n=26;a=1.3652300089597702       ;b=1.3652300238609314       ;c=1.3652300164103508       ;f(a)=-7.355607323233926e-08   ;f(b)=1.7251274897489566e-07   ;f(c)=4.94783378712782e-08     ;delta=7.450580596923828e-09
# n=27;a=1.3652300089597702       ;b=1.3652300164103508       ;c=1.3652300126850605       ;f(a)=-7.355607323233926e-08   ;f(b)=4.94783378712782e-08     ;f(c)=-1.203886768053053e-08   ;delta=3.725290298461914e-09
# n=28;a=1.3652300126850605       ;b=1.3652300164103508       ;c=1.3652300145477057       ;f(a)=-1.203886768053053e-08   ;f(b)=4.94783378712782e-08     ;f(c)=1.8719735095373835e-08   ;delta=1.862645149230957e-09
# n=29;a=1.3652300126850605       ;b=1.3652300145477057       ;c=1.365230013616383        ;f(a)=-1.203886768053053e-08   ;f(b)=1.8719735095373835e-08   ;f(c)=3.340433707421653e-09    ;delta=9.313225746154785e-10
# n=30;a=1.3652300126850605       ;b=1.365230013616383        ;c=1.3652300131507218       ;f(a)=-1.203886768053053e-08   ;f(b)=3.340433707421653e-09    ;f(c)=-4.349217874732858e-09   ;delta=4.656612873077393e-10
# The value of root is: 1.3652300131507218
# 1.365230013

# %% [markdown]
# ### Ví dụ 2: Sai số tương đối
#
# Đánh giá sai số: `|x_n - x_(n-1)| / |x_n| = |b_n - a_n| / |x_n| < epsilon`

# %%
def bisection_recursion_v2 (a,b,e):
    #Error function
    if (f(a) * f(b) >= 0):
        print("You have not assumed right a and b\n")
        return

    #Implementing Bisection Method
    i = 0; temp_c = 0;
    while True:
        # Find middle point
        c = (a+b)/2

        print(f"n={i:<2};a={a:<25};b={b:<25};c={c:<25};f(a)={f(a):<25};f(b)={f(b):<25};f(c)={f(c):<25};sigma={abs(c-temp_c)/abs(c):<25}")

        # Decide the side to repeat the steps
        if (f(c) == 0.0):
            break
        elif (f(c)*sign(a) < 0):
            b = c
        else:
            a = c 
            
        #stopping criteria
        if (i != 0) and ((b-a)/abs(c) < e):
            break
        else:
            temp_c = c
            i += 1
    
    print(f"The value of root is: {c}")
    return c

# %%
def f(x):
    return math.exp(x) - math.cos(2*x)
a = -3
b = -2
e = pow(10, -6)

bisection_recursion_v2 (a, b, e)
# Out:
# n=0 ;a=-3                       ;b=-2                       ;c=-2.5                     ;f(a)=-0.910383218282502       ;f(b)=0.7889789041002246       ;f(c)=-0.20157718683932746     ;sigma=1.0
# n=1 ;a=-2.5                     ;b=-2                       ;c=-2.25                    ;f(a)=-0.20157718683932746     ;f(b)=0.7889789041002246       ;f(c)=0.31619502399264404      ;sigma=0.1111111111111111
# n=2 ;a=-2.5                     ;b=-2.25                    ;c=-2.375                   ;f(a)=-0.20157718683932746     ;f(b)=0.31619502399264404      ;f(c)=0.05541233632268694      ;sigma=0.05263157894736842
# n=3 ;a=-2.5                     ;b=-2.375                   ;c=-2.4375                  ;f(a)=-0.20157718683932746     ;f(b)=0.05541233632268694      ;f(c)=-0.07451630422211637     ;sigma=0.02564102564102564
# n=4 ;a=-2.4375                  ;b=-2.375                   ;c=-2.40625                 ;f(a)=-0.07451630422211637     ;f(b)=0.05541233632268694      ;f(c)=-0.00979114678020486     ;sigma=0.012987012987012988
# n=5 ;a=-2.40625                 ;b=-2.375                   ;c=-2.390625                ;f(a)=-0.00979114678020486     ;f(b)=0.05541233632268694      ;f(c)=0.022765822024195526     ;sigma=0.006535947712418301
# n=6 ;a=-2.40625                 ;b=-2.390625                ;c=-2.3984375               ;f(a)=-0.00979114678020486     ;f(b)=0.022765822024195526     ;f(c)=0.006474264026010826     ;sigma=0.003257328990228013
# n=7 ;a=-2.40625                 ;b=-2.3984375               ;c=-2.40234375              ;f(a)=-0.00979114678020486     ;f(b)=0.006474264026010826     ;f(c)=-0.0016619445961567753   ;sigma=0.0016260162601626016
# n=8 ;a=-2.40234375              ;b=-2.3984375               ;c=-2.400390625             ;f(a)=-0.0016619445961567753   ;f(b)=0.006474264026010826     ;f(c)=0.0024053132508760205    ;sigma=0.0008136696501220504
# n=9 ;a=-2.40234375              ;b=-2.400390625             ;c=-2.4013671875            ;f(a)=-0.0016619445961567753   ;f(b)=0.0024053132508760205    ;f(c)=0.00037146904298147876   ;sigma=0.00040666937779585197
# n=10;a=-2.40234375              ;b=-2.4013671875            ;c=-2.40185546875           ;f(a)=-0.0016619445961567753   ;f(b)=0.00037146904298147876   ;f(c)=-0.0006452920561613451   ;sigma=0.00020329335230737954
# n=11;a=-2.40185546875           ;b=-2.4013671875            ;c=-2.401611328125          ;f(a)=-0.0006452920561613451   ;f(b)=0.00037146904298147876   ;f(c)=-0.0001369250191764898   ;sigma=0.00010165700925078785
# n=12;a=-2.401611328125          ;b=-2.4013671875            ;c=-2.4014892578125         ;f(a)=-0.0001369250191764898   ;f(b)=0.00037146904298147876   ;f(c)=0.00011726864091948785   ;sigma=5.0831088293600365e-05
# n=13;a=-2.401611328125          ;b=-2.4014892578125         ;c=-2.40155029296875        ;f(a)=-0.0001369250191764898   ;f(b)=0.00011726864091948785   ;f(c)=-9.829032769720358e-06   ;sigma=2.5414898213332655e-05
# n=14;a=-2.40155029296875        ;b=-2.4014892578125         ;c=-2.401519775390625       ;f(a)=-9.829032769720358e-06   ;f(b)=0.00011726864091948785   ;f(c)=5.3719593276504995e-05   ;sigma=1.2707610587981142e-05
# n=15;a=-2.40155029296875        ;b=-2.401519775390625       ;c=-2.4015350341796875      ;f(a)=-9.829032769720358e-06   ;f(b)=5.3719593276504995e-05   ;f(c)=2.194522753980188e-05    ;sigma=6.353764923405364e-06
# n=16;a=-2.40155029296875        ;b=-2.4015350341796875      ;c=-2.4015426635742188      ;f(a)=-9.829032769720358e-06   ;f(b)=2.194522753980188e-05    ;f(c)=6.0580842049101635e-06   ;sigma=3.1768723691525693e-06
# n=17;a=-2.40155029296875        ;b=-2.4015426635742188      ;c=-2.4015464782714844      ;f(a)=-9.829032769720358e-06   ;f(b)=6.0580842049101635e-06   ;f(c)=-1.885477577651118e-06   ;sigma=1.58843366145078e-06
# n=18;a=-2.4015464782714844      ;b=-2.4015426635742188      ;c=-2.4015445709228516      ;f(a)=-1.885477577651118e-06   ;f(b)=6.0580842049101635e-06   ;f(c)=2.086302489823222e-06    ;sigma=7.942174615062652e-07
# The value of root is: -2.4015445709228516
# -2.4015445709228516
